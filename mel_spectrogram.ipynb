# %% [markdown]
# <a href="https://colab.research.google.com/github/mapattacker/bioacoustics/blob/master/mel_spectrogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load Audio

# %% [markdown]
#  * **y**: numpy array of audio
#  * **sr**: Sampling rate, # samples in one second

# %%
import librosa
y, sr = librosa.load("XC672602 - Asian Koel - Eudynamys scolopaceus.mp3")
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %% [markdown]
# # Display Audio

# %%
% pylab inline
import os
import pandas as pd
import librosa.display

plt.figure(figsize=(12, 4))
librosa.display.waveplot(data, sr=sampling_rate);
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Play Audio

# %%
import IPython
IPython.display.Audio(data=data, rate=sampling_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# ## Mel Spectrogram

# %%
melspec = librosa.feature.melspectrogram(y, sr=sr)

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()
librosa.display.specshow(librosa.power_to_db(melspec, ref=np.max))
plt.colorbar();
